# %%
import pandas as pd

# %%
import numpy as np

# %%
df_food = pd.read_csv(r"C:\Users\STANLEY OKALI\Desktop\food.csv", encoding ='cp1252')

# %%
df_food
# Out:
#        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# 0               Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
df_food.describe(include='all')
# Out:
#            Area Code   Area     Item Code                     Item  \
# count   60943.000000  60943  60943.000000                    60943
# unique           NaN     49           NaN                      119
# top              NaN  Kenya           NaN  Milk - Excluding Butter
# freq             NaN   1560           NaN                     1262
# mean      134.265576    NaN   2687.176706                      NaN
# std        72.605709    NaN    146.055739                      NaN
# min         4.000000    NaN   2501.000000                      NaN
# 25%        74.000000    NaN   2562.000000                      NaN
# 50%       136.000000    NaN   2630.000000                      NaN
# 75%       195.000000    NaN   2775.000000                      NaN
# max       276.000000    NaN   2961.000000                      NaN
#
#         Element Code                   Element         Unit          Y2014  \
# count   60943.000000                     60943        60943   59354.000000
# ...

# %%
df_food.groupby('Item')['Item'].count()
df_food[['Item']] = df_food[['Item']].fillna(value='mcf')

# %%
df_food.groupby('Item')['Item'].count()
# Out:
# Item
# Alcohol, Non-Food      283
# Alcoholic Beverages    564
# Animal Products        135
# Animal fats            639
# Apples and products    517
#                       ...
# Vegetables, Other      583
# Vegetal Products       135
# Wheat and products     653
# Wine                   497
# Yams                   383
# Name: Item, Length: 119, dtype: int64

# %%
df_food['Item'].sum()
# Out:
# 'PopulationPopulationGrand TotalGrand TotalGrand TotalVegetal ProductsVegetal ProductsVegetal ProductsAnimal ProductsAnimal ProductsAnimal ProductsCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerCereals - Excluding BeerWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsWheat and productsRice and productsRice and productsRice and productsRice and productsRice and productsRice and productsRice and productsRice and productsRice and productsRice and productsRice and 
# ...

# %%
df_food.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
df_food.groupby('Element')['Element'].count().sum()
# Out:
# 60943

# %%
df_food.unique()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-07f3306f9ad3> in <module>
# ----> 1 df_food.unique()
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'unique'

# %%
df_food.groupby('Area')['Area'].nunique().sum()
# Out:
# 49

# %%
df_food.groupby('Element')['Element'].count().sum()
# Out:
# 60943

# %%
df_food.groupby('Area')['Y2018'].count()
# Out:
# Area
# Algeria                        1298
# Angola                         1396
# Benin                          1252
# Botswana                       1361
# Burkina Faso                   1373
# Cabo Verde                     1192
# Cameroon                       1432
# Central African Republic       1308
# Chad                           1305
# Comoros                          45
# Congo                          1377
# Côte d'Ivoire                  1455
# Djibouti                       1040
# Egypt                          1468
# Eswatini                       1231
# Ethiopia                       1425
# Ethiopia PDR                     39
# Gabon                          1192
# Gambia                         1118
# Ghana                          1337
# Guinea                         1385
# Guinea-Bissau                  1091
# Kenya                          1548
# Lesotho                        1094
# Liberia                        1133
# Madagascar                     1424
# ...

# %%
df_food.groupby('Element')['Y2014'].sum().sum()
# Out:
# 7965086.130000004

# %%
df_food.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].count()
# Out:
# <ipython-input-55-743cfa0b9aa2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_food.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].count()
#                                         Y2014  Y2015  Y2016  Y2017  Y2018
# Element
# Domestic supply quantity                 5244   5245   5250   5258   5256
# Export Quantity                          3660   3704   3653   3660   3646
# Fat supply quantity (g/capita/day)       4965   4974   4980   4982   4987
# Feed                                     1216   1177   1215   1213   1225
# Food                                     4896   4901   4910   4912   4913
# Food supply (kcal/capita/day)            4947   4955   4963   4965   4969
# Food supply quantity (kg/capita/yr)      4860   4865   4874   4876   4877
# Import Quantity                          4919   4911   4908   4929   4945
# ...

# %%
df_food.groupby('Item')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
# Out:
# <ipython-input-57-eb819c298b95>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_food.groupby('Item')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
#                          Y2014      Y2015      Y2016      Y2017      Y2018
# Item
# Alcohol, Non-Food      2403.00    2180.00    2223.00    2348.00    2293.00
# Alcoholic Beverages  102410.11   98783.72   96958.75   95581.06   97847.27
# Animal Products       11935.65   11811.73   11661.69   11547.65   11578.61
# Animal fats          209460.54  200675.72  183314.22  269617.53  269648.27
# Apples and products    9499.23   10559.15    9853.26   10198.90    9640.51
# ...                        ...        ...        ...        ...        ...
# Vegetables, Other    155038.96  158104.08  156218.90  157752.59  163987.21
# Vegetal Products     107145.19  107064.17  106792.72  107655.20  107775.39
# ...

# %%
df_food.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
# Out:
# <ipython-input-58-b317b3d9e121>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df_food.groupby('Element')['Y2014','Y2015','Y2016','Y2017','Y2018'].sum()
#                                              Y2014       Y2015       Y2016  \
# Element
# Domestic supply quantity                1996716.35  2021493.55  2044842.70
# Export Quantity                          150020.64   157614.47   151920.46
# Fat supply quantity (g/capita/day)        10225.56    10235.74    10102.77
# Feed                                     216927.89   225050.22   228958.65
# Food                                    1212332.49  1232361.10  1247022.17
# Food supply (kcal/capita/day)            454257.00   453383.00   451810.00
# Food supply quantity (kg/capita/yr)       49650.63    49345.13    48985.28
# Import Quantity                          274144.48   267018.46   286582.78
# ...
